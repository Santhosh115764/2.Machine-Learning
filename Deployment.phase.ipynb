# %%
import pickle

# %%
loaded_model=pickle.load(open("finalized_model_mul_linear.sav",'rb'))
result=loaded_model.predict([[162597,151377,443898,191792,1]])
# Out:
# C:\SanthoshMSD\Anaconda 1\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[88956282.05415764]])
